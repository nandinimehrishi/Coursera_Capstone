# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

#Create a handle, wikipedia_page, to handle the contents of the website
wikipedia_page=requests.get(wikipedia_link)

#Store the contents of the website under wikipedia_page
wikipedia_page = lh.fromstring(wikipedia_page.content)

#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = wikipedia_page.xpath('//tr')

#Check the length of the first 12 rows
[len(T) for T in tr_elements[:12]]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
tr_elements = wikipedia_page.xpath('//tr')

#Create empty list
col=[]

i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print(name)
    col.append((name,[]))
# Out:
# Postal Code
#
# Borough
#
# Neighborhood

# %%
col
# Out:
# [('Postal Code\n', []), ('Borough\n', []), ('Neighborhood\n', [])]

# %%
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 3, the //tr data is not from our table 
    if len(T)!=3:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [362, 362, 362]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df = df.replace(r'\n','', regex=True)
df.columns = ['Postcode', 'Borough', 'Neighbourhood']
df.head()
# Out:
#   Postcode           Borough              Neighbourhood
# 0      M1A      Not assigned               Not assigned
# 1      M2A      Not assigned               Not assigned
# 2      M3A        North York                  Parkwoods
# 3      M4A        North York           Victoria Village
# 4      M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
df.drop(df[df['Borough'] == 'Not assigned'].index, inplace=True)
df.index = range(len(df))
df
# Out:
#     Postcode                Borough  \
# 0        M3A             North York
# 1        M4A             North York
# 2        M5A       Downtown Toronto
# 3        M6A             North York
# 4        M7A       Downtown Toronto
# 5        M9A              Etobicoke
# 6        M1B            Scarborough
# 7        M3B             North York
# 8        M4B              East York
# 9        M5B       Downtown Toronto
# 10       M6B             North York
# 11       M9B              Etobicoke
# 12       M1C            Scarborough
# 13       M3C             North York
# 14       M4C              East York
# 15       M5C       Downtown Toronto
# 16       M6C                   York
# 17       M9C              Etobicoke
# 18       M1E            Scarborough
# 19       M4E           East Toronto
# 20       M5E       Downtown Toronto
# 21       M6E                   York
# 22       M1G            Scarborough
# 23       M4G              East York
# 24       M5G       Downtown Toronto
# 25       M6G       Downtown Toronto
# 26       M1H            Scarborough
# 27       M2H             North York
# 28       M3H             North York
# 29       M4H              East York
# ..       ...                    ...
# 178      M5R        Central Toronto
# 179      M6R           West Toronto
# 180      M7R            Mississauga
# 181      M9R              Etobicoke
# 182      M1S            Scarborough
# 183      M4S        Central Toronto
# 184      M5S       Downtown Toronto
# 185      M6S           West Toronto
# 186      M1T            Scarborough
# 187      M4T        Central Toronto
# 188      M5T       Downtown Toronto
# 189      M1V            Scarborough
# 190      M4V        Central Toronto
# 191      M5V       Downtown Toronto
# 192      M8V              Etobicoke
# 193      M9V              Etobicoke
# 194      M1W            Scarborough
# 195      M4W       Downtown Toronto
# 196      M5W       Downtown Toronto
# 197      M8W              Etobicoke
# 198      M9W              Etobicoke
# 199      M1X            Scarborough
# 200      M4X       Downtown Toronto
# 201      M5X       Downtown Toronto
# 202      M8X              Etobicoke
# 203      M4Y       Downtown Toronto
# 204      M7Y           East Toronto
# 205      M8Y              Etobicoke
# 206      M8Z              Etobicoke
# 207           Canadian postal codes
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                            Regent Park, Harbourfront
# 3                     Lawrence Manor, Lawrence Heights
# 4          Queen's Park, Ontario Provincial Government
# 5              Islington Avenue, Humber Valley Village
# 6                                       Malvern, Rouge
# 7                                            Don Mills
# 8                      Parkview Hill, Woodbine Gardens
# 9                             Garden District, Ryerson
# 10                                           Glencairn
# 11   West Deane Park, Princess Gardens, Martin Grov...
# 12              Rouge Hill, Port Union, Highland Creek
# 13                                           Don Mills
# 14                                    Woodbine Heights
# 15                                      St. James Town
# 16                                  Humewood-Cedarvale
# 17   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 18                   Guildwood, Morningside, West Hill
# 19                                         The Beaches
# 20                                         Berczy Park
# 21                                 Caledonia-Fairbanks
# 22                                              Woburn
# 23                                             Leaside
# 24                                  Central Bay Street
# 25                                            Christie
# 26                                           Cedarbrae
# 27                                   Hillcrest Village
# 28     Bathurst Manor, Wilson Heights, Downsview North
# 29                                    Thorncliffe Park
# ..                                                 ...
# 178                The Annex, North Midtown, Yorkville
# 179                             Parkdale, Roncesvalles
# 180              Canada Post Gateway Processing Centre
# 181  Kingsview Village, St. Phillips, Martin Grove ...
# 182                                          Agincourt
# 183                                         Davisville
# 184                     University of Toronto, Harbord
# 185                                 Runnymede, Swansea
# 186            Clarks Corners, Tam O'Shanter, Sullivan
# 187                        Moore Park, Summerhill East
# 188          Kensington Market, Chinatown, Grange Park
# 189  Milliken, Agincourt North, Steeles East, L'Amo...
# 190  Summerhill West, Rathnelly, South Hill, Forest...
# 191  CN Tower, King and Spadina, Railway Lands, Har...
# 192       New Toronto, Mimico South, Humber Bay Shores
# 193  South Steeles, Silverstone, Humbergate, Jamest...
# 194                      Steeles West, L'Amoreaux West
# 195                                           Rosedale
# 196                                     Stn A PO Boxes
# 197                             Alderwood, Long Branch
# 198                Northwest, West Humber - Clairville
# 199                                        Upper Rouge
# 200                        St. James Town, Cabbagetown
# 201             First Canadian Place, Underground city
# 202      The Kingsway, Montgomery Road, Old Mill North
# 203                               Church and Wellesley
# 204  Business reply mail Processing Centre, South C...
# 205  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 206  Mimico NW, The Queensway West, South of Bloor,...
# 207
#
# [208 rows x 3 columns]

# %%
df.shape
# Out:
# (208, 3)
